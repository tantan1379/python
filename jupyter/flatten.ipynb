# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ec9e82462a6e> in <module>
#      17 from sklearn import linear_model
#      18 from sklearn.preprocessing import PolynomialFeatures
# ---> 19 import ImportHandler
#      20 #sigma for Gaussian filter
#      21 sigma = (4.0,2.0)
#
# f:\MyGit\jupyter\ImportHandler.py in <module>
#      17 from skimage import io
#      18 import os
# ---> 19 from Visualization.Heatmap import calculateHeatmap
#      20 from Algorithms.SlowScanRegistration import RPEBasedRegistration
#      21 import scipy.io
#
# ModuleNotFoundError: No module named 'Visualization'
